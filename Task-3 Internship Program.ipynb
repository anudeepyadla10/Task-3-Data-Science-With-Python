# %% [markdown]
# # Data Visualization
#
# ### Data visualization is the graphical representation of information and data.By using visual elements like charts, graphs, and maps, data visualization tools provide an accessible way to see and understand trends, outliers, and patterns in data.

# %% [markdown]
# # Data Visualization using Matplotlib
# ### Matplotlib is a low-level library of Python which is used for data visualization. It is easy to use and emulates MATLAB like graphs and visualization. This library is built on the top of NumPy arrays and consist of several plots like line chart, bar chart, histogram, etc¶

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Plotting Using CSV file..

# %%
# Importing a CSV file..
data=pd.read_csv('householdtask3.csv')
data
# Out:
#     year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0   2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1   2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2   2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3   2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4   2008   312240   217657  141318      69.7         45.3      20.0  31.5
# ..   ...      ...      ...     ...       ...          ...       ...   ...
# 65  2020   352564   213893  119637      60.7         33.9      20.1  36.9
# 66  2020   350182   235256  141104      67.2         40.3      19.9  35.0
# 67  2020   351328   288779  187838      82.2         53.5      20.0  39.6
# 68  2020   329588   156459  107753      47.5         32.7      18.8  31.1
# 69  2020   388013   314154   38270      81.0          9.9      22.1  69.8
#
#     size  income  expenditure  eqv_income  eqv_exp
# ...

# %% [markdown]
# # Basic Charts for Data Visualization
# ## 1. Bar Chart or plot:
# ### A bar chart is a pictorial representation of the numerical data by a number of bars of a uniform width with different heights, erected horizontally or vertically with equal spacing between them.

# %%
# Bar chart or Bar plot..
plt.bar(data['year'],data['own'])

#adding title to the plot..
plt.title("Bar Chart")

#Setting the x and y labels..
plt.xlabel('year')
plt.ylabel('own')

plt.legend( ["HouseholdTask"],loc="upper left")

plt.show()

# %% [markdown]
# # 2.Line chart:
# ### Line chart or Line graph is used to symbolize facts through the years series. It presentations records as a series of records points called as markers, connected with the aid of line segments showing the between values over the years.

# %%
# Line Plot or Chart..
plt.plot(data['year'],data['own'])

# Adding title to the plot..
plt.title('Line Plot')

#Adiing labels x & y..
plt.xlabel('Year')
plt.ylabel('age')

plt.legend(['year & age'],loc="upper left")
plt.show()

# %% [markdown]
# # 3.Scatter Chart (Plots):
# ### A scatter chart or scatter plot chart is a effective information visualization device, makes use of dots to symbolize information factors. Scatter chart is used to display and examine variables which enables find courting between the ones variables.

# %%
# Scatter plot with year
plt.scatter(data['year'],data['income'])

#Adding title to the plot..
plt.title("scatter plot")

#setting the x and y labels..
plt.xlabel('year')
plt.ylabel('income')

#Showing the result..
plt.show()

# %% [markdown]
# # 4. Histogram :
# ### A histogram represents the distribution of numerical facts by using dividing it into periods (packing containers) and displaying the frequency of records as bars. It is commonly used to visualize the underlying distribution of a dataset and discover styles inclusive of skewness, valuable tendency, and variability.

# %%
# histogram
plt.hist(data['expenditure'])

#Adding the title..
plt.title("Histogram")

# showing the result..
plt.show()

# %%
#plotting two histograms income and expenditure..
plt.hist(data['income'])
plt.hist(data['expenditure'])

#Adding the title..
plt.title("Histogram")

# showing the result..
plt.show()
